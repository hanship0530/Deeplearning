# %%
'''
CCI INDEX
M = (data_pd['High'][20:] + data_pd['Low'][20:] + data_pd['Close'][20:]) / 3
sma20 = M.rolling(window=20).mean()
sma20.head()
data_pd['CCI'] = M-sma20[20:]/(0.015*abs(M-sma20[20:]))
'''

# %%
'''
MFI INDEX
'''

# %%
import pyti.money_flow_index as mfi

# %%
import matplotlib.pyplot as plt
import fix_yahoo_finance as yf

# %%
data = yf.downloads('AAPL','2018-01-01','2019-02-03')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-8c52174f91db> in <module>
# ----> 1 data = yf.downloads('AAPL','2018-01-01','2019-02-03')
#
# AttributeError: module 'fix_yahoo_finance' has no attribute 'downloads'

# %%
data.Close.plot()
plt.show()

# %%
import pandas as pd

# %%
data_pd = pd.DataFrame(data)
